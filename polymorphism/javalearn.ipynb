// %%
public class demo{
    public static void main(String[] args){
        int face=8;
        short diff=400;
        byte snif= 10;
        long ice=123532423;
        double dam=1.34234234;
        System.out.println(dam);
    }



}
demo.main(null)
// Out:
// 1.34234234

// %%
int a=10;
int y;
System.out.println(y)
// Out:
// 0

// %%
float f=8.103f;
System.out.printf("%.20f%n",f)
// Out:
// 8.10299968719482400000
// java.io.PrintStream@e2d2d16

// %%
float f = 8.103f;
System.out.printf("%.20f%n", f);
// Out:
// 8.10299968719482400000
// java.io.PrintStream@e2d2d16

// %%
int i= 300;
byte c=(byte)i;
System.out.println(c);
// Out:
// 44

// %%
char c='a';
int i = c;
System.out.println(i);
// Out:
// 97

// %%
float f=44.23423f;
int i=(int)f;
System.out.println(i);
// Out:
// 44

// %%
int a;
int b;
a+=5;
b=7;
boolean c=(a!=b);
System.out.println(c)
// Out:
// true

// %%
boolean a=true;
boolean b=true;
int i=2;
if (i%2==0){
System.out.println("yeah lets do it");
if (b==true){
    System.out.println("yeah lets do it again");
}
}
else{
    System.out.println("not good not good");
}
while ( i<6){
    System.out.println("i is less then 6");
    i++;
}
// Out:
// yeah lets do it
// yeah lets do it again
// i is less then 6
// i is less then 6
// i is less then 6
// i is less then 6

// %%
for ( int i = 0;i<=10;i+=2){
    System.out.println("enzyme");
}
// Out:
// enzyme
// enzyme
// enzyme
// enzyme
// enzyme
// enzyme

// %%
class Student{
    String name;
    int age;
    int roll;
    String collage;

    void markAttendance(){
        System.out.println("Attendance marked by"+name);
    }
    void print(){
        System.out.println("this is t"+name+" "+age);
    }
}

Student s1 =new Student();

s1.name ="aditya";
s1.age=28;
s1.roll=101;
s1.collage="efaoijf";
s1.markAttendance();

s1.print();
// Out:
// Attendance marked byaditya
// this is taditya 28

// %%
class hello:
    name=9
    same="hennl"

s=hello()
s.name
// Out:
// 9

// %%
class Steam{
    String name= "name";
    int age=19;
    int roll=54;
    String collage="healef";
    Steam(){}

    Steam(int age,int roll,String name, String Collage){
        age=90;
        roll=32;
        name="zeeshan";
        collage="DTU";
    }
    System.out.println("hello ha"+age+" "+String+" "+roll)

}

Steam s1=new Steam(83,45,"kishan","tier 3")
// Out:
// |       System.out.println("hello ha"+age+" "+String+" "+roll)
// <identifier> expected
//
// |       System.out.println("hello ha"+age+" "+String+" "+roll)
// illegal start of type

// %%
class Steam {
    String name = "name";
    int age = 19;
    int roll = 54;
    String collage = "healef";

   
    Steam() {
        System.out.println("Default constructor called");
    }

   
    Steam(int age, int roll, String name, String collage) {
        this.age = age;
        this.roll = roll;
        this.name = name;
        this.collage = collage;
        System.out.println("hello ha " + this.age + " " + this.name + " " + this.roll + " " + this.collage);
    }
}

Steam s1=new Steam()
// Out:
// Default constructor called

// %%
int y;
y=0;
System.out.println(y);
// Out:
// 0
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %% [markdown]
// default

// %%
class Car{
    String color;
    int year;
    int no;
    
    Car(){

    }
    Car(String color){
        this.color=color;
        System.out.println(color+" "+year+" "+no);
    }
    Car(String color,int year){
        this.color=color;
        this.year=year;
        System.out.println(color+" "+year+" "+no);
    }
    Car(String color,int year,int no){
        this.color=color;
        this.year=year;
        this.no=no;
        System.out.println(color+" "+year+" "+no);
    }
    
}

Car s1=new Car("white",19,12);
System.out.println(s1.color)
// Out:
// white 19 12
// white

// %% [markdown]
// chain constructor

// %%
class Car{
    String color;
    int year;
    int no;
    
    Car(){

    }
    Car(String color){
        this(String color)
        System.out.println(color+" "+year+" "+no);
    }
    Car(String color,int year){
        this.color=color;
        this.year=year;
        System.out.println(color+" "+year+" "+no);
    }
    Car(String color,int year,int no){
        this.color=color;
        this.year=year;
        this.no=no;
        System.out.println(color+" "+year+" "+no);
    }
    
}

Car s1=new Car("white",19);
System.out.println(s1.color)
// Out:
// white 19 0
// white

// %%
class Car{
    String color;
    int year;
    int no;
    
    Car(){
        this("none");
        System.out.println("zero");
    }
    Car(String color){
        this(color,0);
        System.out.println("first");
        System.out.println(color);
    }
    Car(String color,int year){
        this(color,0,0);
        System.out.println("second");
        System.out.println(color+year);
    }
    Car(String color,int year,int no){
        this.color=color;
        this.year=year;
        this.no=no;
        System.out.println("third");
        System.out.println(color+year+no);
    }
}
Car s1=new Car();
// Out:
// third
// none00
// second
// none0
// first
// none
// zero

// %%
class Student{
    int roll;
    String name;
    String section;

    Student(){

    }
    Student(int roll){
        this.roll=roll;
    }
}
Student s1=new Student(32);
Student s2=new Student();
System.out.println(s1.roll+" "+s2.roll)
// Out:
// 32 0

// %%
char i='A';
int b=++i;
System.out.println(b);
// Out:
// 66

// %%
class Collage{
    int roll;
    String name;
    String clas;
}
Collage kishan=new Collage();
System.out.println(kishan.name);
// Out:
// |       roll=10;
// <identifier> expected
//
// |       name="kishan";
// <identifier> expected
//
// |       clas="LUM_E";
// <identifier> expected

// %% [markdown]
// primittive data type has some defualt value
//
// non-primittive data type - they belong to particular class - defualt value of non premeittive data type is null

// %%
int x;
x=10;
System.out.println(x);
// Out:
// 10

// %%
class Collage{
    int roll;
    String name;
    String clas;
    Collage(){
        this.roll=0;
        this.name="None";
        this.clas="None";
    }
    Collage(int x){
        this.roll=x;
        this.name="None";
        this.clas="None";
    }
    Collage(int x,String y){
        this.roll=x;
        this.name=y;
        this.clas="None";
    }
}
Collage kishan=new Collage(7);
Collage rathore=new Collage(8,"singh");
Collage prince=new Collage();

System.out.println(kishan.clas+" "+rathore.clas+" "+prince.clas)
// Out:
// None None None

// %% [markdown]
// how to calculate the size of class

// %% [markdown]
// #### static method
// if you want to make a common variable to all object like collage name of same collage studets so you have to create variable in every object that will increase the size of the object

// %% [markdown]
// we can create a static variable by just mentioning stating in front of them

// %%
class Collage{
    int roll;
    String name;
    String clas;
    static String colname="GLA";
    static int count=0;
   
    Collage(){
        this.roll=0;
        this.name="None";
        this.clas="None";
        count++;
    }
    Collage(int x){
        this.roll=x;
        this.name="None";
        this.clas="None";
        count++;
    }
    Collage(int x,String y){
        this.roll=x;
        this.name=y;
        this.clas="None";
        count++;
    }
    static void counter(){

        
    }
}

Collage s2=new Collage(0,"rishik");
Collage s3=new Collage(0,"rishik");
System.out.println(Collage.count*32);
System.out.println(s2.colname+ " "+ s3.colname+" we are calling the static variable from the class"+Collage.colname);
// Out:
// 128
// GLA GLA we are calling the static variable from the classGLA

// %% [markdown]
// * this static method doesnt have access to object

// %% [markdown]
// like variable u can also create method , static method which can directly call by class

// %% [markdown]
// one major example of this use case is to count the object you have been crated , by creating one static varible count to hold count and incrase this count value in every constructor ,and at the end printing the count value by a static method

// %% [markdown]
// now lets learn about final:
// final keyword is used for exact value , so that no body can change it :
// like its parmamnently its become fixed

// %% [markdown]
// can we use this finaly keyword in
// * varibale ✅
// * method ✅
// * class ✅
// * parameter ✅

// %%
class Collage {
    private int roll;
    private String name;
    String clas;
    static String uni = "iit";

    
    final String country = "India";  

    Collage(int x, String y, String z) {
        this.roll = x;
        this.name = y;
        this.clas = z;
    }

    
    final void showCountry() {
        System.out.println("Country: " + country);
    }

    void display() {
        System.out.println("Roll: " + roll + ", Name: " + name + ", Class: " + clas + ", University: " + uni);
    }
}


final class Rules {
    void showRule() {
        System.out.println("Collage rules are strict!");
    }
}
Collage s1=new Collage();
System.out.println()

// %% [markdown]
// encapsulation
//
// why we need it
//
// access modifier
// * variable
// * methods
// * constructor
// * class
//
//  4 type of modifier
// * public
// * defualt
// * protected
// * private

// %%
class bank{
    private double balance;
    default 
    public
    protected

    
}

// %% [markdown]
// private we can only access inside the class
//
// defualt : anyone can access belong to same package  that means the file where you can write all the class includeing your main class

// %%
class bank{
    private double balance=0;
        

    public void withdraw(int amount){
        if (amount<balance){
            balance-=amount;
        }
        else{
            System.out.println("insufficient balance");
        }
    }
      public void deposit(double amount){
       
            balance+=amount;
       
    }

    public  double check(){
        return balance;
    }


}

bank s1=new bank();
s1.deposit(300);
s1.check();
s1.withdraw(200);
s1.check();
// Out:
// 100.0

// %% [markdown]
// why we use getter and setter , the difference between calling property with method and without method
// we do it because we can add validation

// %%
public class Bank{
    private double balance;
    public String name;
    private int AccountNo;

    Bank(){
        this(0.0);
    }
    Bank(double x){
        this(x,"None");
    }
    Bank(double x,String y){
        this(x,y,0);
    }
    Bank(double x,String y,int z){
        this.balance=x;
        this.name=y;
        this.AccountNo=z;
    }

    public void widthdraw(double ammount){
        if (this.balance==0 || ammount>this.balance){
            System.out.println("insufficient balance");
        }
        else{
            this.balance=this.balance-ammount;
        }

    }
    public void deposit(double amount){
        this.balance=this.balance+amount;
    }
    public void check(){
        System.out.println(this.balance);
    }

}
Bank s1=new Bank(384,"rahul",232135324);
s1.check();
// Out:
// 384.0

// %%
class Student{
    int roll;
    String name;
    Student(){

    }
    Student(int r,String n){
        this.roll=r;
        this.name=n;
    }
    void print(){
    }
}
class Medical extends Student{
    String sub;
    Medical(){

    }
    Medical(String sub,int r,String n){
        this.sub=sub;
        this.roll=r;
        this.name=n;
    }
    void print(){
        System.out.println(roll+" "+name+" "+sub);
    }

}

// Medical s1=new Medical("biology");
// s1.print();
Medical s2=new Medical("Biology",45,"kishan");
s2.print();
// Student s1=new Medical("Biology",67,"ravi");
// s1.print();
// Out:
// 45 kishan Biology

// %%
class Bird{
    boolean feather;
    Bird(){
    }
    Bird(boolean x){
        this.feather=x;
    }
    void speak(){
        System.out.println("all bird has sound");
    }
    void print(){

    }
}
class Parrot extends Bird{
    boolean fly;
    boolean swim;
    Parrot(){
    }
    Parrot(boolean f,boolean s,boolean feather){
        this.fly=f;
        this.swim=s;
        this.feather=feather;
    }
    void print(){
        System.out.println("can parrot fly="+fly+" can parrot swim="+swim +"does it has feather"+feather);
    }
}

class Penguin extends Bird{
    boolean fly;
    boolean swim;
    Penguin(){

    }
    Penguin(boolean f,boolean s,boolean feather){
        this.fly=f;
        this.swim=s;
        this.feather=feather;
    }
     void print(){
        System.out.println("can parrot fly="+fly+" can parrot swim="+swim +"does it has feather"+feather);

    }
}

Bird s1=new Penguin(false,true,true);
s1.print();
Bird s2=new Parrot(true,false,true);
s2.print();
// Out:
// can parrot fly=false can parrot swim=truedoes it has feathertrue
// can parrot fly=true can parrot swim=falsedoes it has feathertrue

// %%
class Bird{
    String speak;
    Bird(){

    }
    Bird(String s){
        this.speak=s;
    }
    void sound(){
        System.out.println("chirp chirp");
    }
    void print(){

    }
}
class Chicken extends Bird{
    boolean speak;
    boolean eatable;
   
    Chicken(){

    }
    Chicken(boolean eat,String s){
        super(s);
        this.eatable=eat;
    }
    void sound(){
        super.sound();
        System.out.println("kukduku");
    }
    void print(){
        System.out.println("can we eat it="+eatable+" " +"can it speak= "+super.speak);
    }

}
Bird s1=new Chicken(true,"no it cant speak");
s1.sound();
s1.print();
// Out:
// chirp chirp
// kukduku
// can we eat it=true can it speak= no it cant speak

// %%
class Student {
    String name;
    int age;
    int rollno;
    int x;
    Student(){

    }
    Student ( String n,int a, int r){
        this.name=n;
        this.rollno=r;
        this.age=a;
    }
}

class Engi extends Student{
    String collage;
    Engi(){

    }
    Engi(String c){
        this.collage=c;
    }
    void print(){
        System.out.println(name+" "+age+" "+rollno+" "+collage); 
    //as u can see name variable is unique and age and roll no too 
    //so we dont need to mantion super in that
    //we need to mention super when both class has same variable name 
    //and we want to use the parent class variable
}
}
Engi s1=new Engi("GLA");
s1.print();
// Out:
// null 0 0 GLA

// %% [markdown]
// Abstraction , abstract keyword let you declare method without creating its body that means no need for { } brackets
//
// well you need to also mention abstract keyword in front of class

// %%
// Abstract class
abstract class Employee {
    String name;
    int id;

    Employee(String name, int id) {
        this.name = name;
        this.id = id;
    }

    // Abstract method (must be implemented by subclasses)
    abstract void calculateSalary();

    // Concrete method (common to all employees)
    void showDetails() {
        System.out.println("Name: " + name + ", ID: " + id);
    }
}

// Subclass 1
class FullTimeEmployee extends Employee {
    double monthlySalary;

    FullTimeEmployee(String name, int id, double monthlySalary) {
        super(name, id);
        this.monthlySalary = monthlySalary;
    }

    void calculateSalary() {
        System.out.println("Full-time Salary: " + monthlySalary);
    }
}

// Subclass 2
class PartTimeEmployee extends Employee {
    int hoursWorked;
    double hourlyRate;

    PartTimeEmployee(String name, int id, int hoursWorked, double hourlyRate) {
        super(name, id);
        this.hoursWorked = hoursWorked;
        this.hourlyRate = hourlyRate;
    }

    void calculateSalary() {
        System.out.println("Part-time Salary: " + (hoursWorked * hourlyRate));
    }
}


Employee e1 = new FullTimeEmployee("Rahul", 101, 30000);
e1.showDetails();
e1.calculateSalary();

Employee e2 = new PartTimeEmployee("Amit", 102, 80, 200);
e2.showDetails();
e2.calculateSalary();
// Out:
// Name: Rahul, ID: 101
// Full-time Salary: 30000.0
// Name: Amit, ID: 102
// Part-time Salary: 16000.0

// %%
public class Demo2 {
    public static void main(String[] args) {
        Car car = new FuelCar();
        car.start();
        car.accelerate();
        car.brake();
    }
}

interface Car {
    void start();

    void accelerate();

    void brake();
}

class FuelCar implements Car {
    
    @Override
    public void start() {
        System.out.println("Fuel car has started");
    }

    @Override
    public void accelerate() {
        System.out.println("Fuel car is accelerating");
    }

    @Override
    public void brake() {
        System.out.println("Fuel car is stopping");
    }

}

class ElectricCar implements Car {

    @Override
    public void start() {
        System.out.println("Electric car has started");
    }

    @Override
    public void accelerate() {
        System.out.println("Electric car is accelerating");
    }

    @Override
    public void brake() {
        System.out.println("Electric car is stopping");
    }

}
